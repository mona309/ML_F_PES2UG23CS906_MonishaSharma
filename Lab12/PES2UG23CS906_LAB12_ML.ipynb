# %% [markdown]
# # **Part A**
# Count / Frequency based Naive Bayes Classifier

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score
)

# =======================================================
# TODO: Students must implement the following steps:
# 1. Complete the fit method in NaiveBayesClassifier (4 TODOs for log prior and log likelihood calculation).
# 2. Complete the predict method in NaiveBayesClassifier (2 TODOs for log probability accumulation and final argmax).
# 3. Complete the data loading calls in Section 2.
# 4. Initialize CountVectorizer with proper parameters in Section 3a.
# 5. Complete the feature transformation (fit_transform and transform) in Section 3a.
# 6. Initialize and fit the custom nb_model in Section 3b.
# 7. Use the fitted nb_model to generate predictions in Section 4.
# =======================================================


# Data loading function (DO NOT CHANGE)
def load_pubmed_rct_file(filepath):
    """
    Reads a .txt file from the PubMed 20k RCT dataset.
    Returns a DataFrame with 'label' and 'sentence'.
    """
    labels, sentences = [], []
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line or '\t' not in line:
                continue
            label, sent = line.split('\t', maxsplit=1)
            labels.append(label)
            sentences.append(sent)
    return pd.DataFrame({'label': labels, 'sentence': sentences})


# Implementing Multinomial Naive Bayes from scratch
# Implementing Multinomial Naive Bayes from scratch
class NaiveBayesClassifier:
    """
    Multinomial Naive Bayes Classifier implemented from scratch.
    It is suitable for both Count and TF-IDF features.
    """
    def __init__(self, alpha=1.0):
        self.alpha = alpha
        self.class_priors = {}
        self.feature_log_probs = {}
        self.classes = None
        self.vocabulary_size = 0

    def fit(self, X_counts, y):
        y_array = y.to_numpy()
        self.classes = np.unique(y_array)
        self.vocabulary_size = X_counts.shape[1]

        for c in self.classes:
            X_c = X_counts[y_array == c]

            # // TODO: Calculate the log prior and store it in self.class_priors[c]
            # Calculate Class Prior P(C): log(P(C))
            # P(C) = (Number of samples in class c) / (Total number of samples)
            class_count = X_c.shape[0]
            total_samples = X_counts.shape[0]
            self.class_priors[c] = np.log(class_count / total_samples)

            feature_sum = X_c.sum(axis=0).A1
            total_mass = np.sum(feature_sum)

            # Apply Laplace smoothing (additive smoothing, alpha=1.0 default):
            # P(w_i | C) = (count(w_i, C) + alpha) / (total_words_in_C + alpha * vocab_size)

            # // TODO: Calculate the numerator (with Laplace smoothing)
            numerator = feature_sum + self.alpha

            # // TODO: Calculate the denominator (with Laplace smoothing)
            denominator = total_mass + self.alpha * self.vocabulary_size

            # // TODO: Calculate the log likelihood (log(numerator / denominator))
            self.feature_log_probs[c] = np.log(numerator / denominator)

    def predict(self, X_counts):
        y_pred = []
        for i in range(X_counts.shape[0]):
            scores = {}

            x_i = X_counts.getrow(i)

            for c in self.classes:
                log_prob = self.class_priors[c]
                log_likelihoods = self.feature_log_probs[c]

                non_zero_indices = x_i.indices
                non_zero_data = x_i.data

                # // TODO: Complete the log probability calculation for the likelihood term
                # Add log likelihoods contribution (Log-Sum Trick):
                # log_prob += sum(count(w_i) * log(P(w_i|C)))
                log_prob += np.sum(non_zero_data * log_likelihoods[non_zero_indices])

                scores[c] = log_prob

            # // TODO: Find the key (class label) with the maximum score
            predicted_class = max(scores, key=scores.get)

            y_pred.append(predicted_class)

        # // TODO: Return the final predictions array
        return np.array(y_pred)
# Out:
# /home/mona/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
# Load and Prepare Data (DO NOT CHANGE)
dir_path = 'Dataset/'

def load_pubmed_rct_file(filepath):
    """
    Loads a PubMed RCT-format dataset file.
    Each line is formatted as: <LABEL>\t<SENTENCE>
    Lines starting with ### are document boundaries and are skipped.
    """
    labels, sentences = [], []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            line = line.strip()
            if not line or line.startswith("###"):  # Skip empty lines or doc markers
                continue
            try:
                label, sentence = line.split('\t', 1)
                labels.append(label)
                sentences.append(sentence)
            except ValueError:
                # Skip malformed lines that don't contain a tab
                continue
    return pd.DataFrame({'label': labels, 'sentence': sentences})


try:
    print(os.path.join(dir_path, 'train.txt'), os.path.join(dir_path, 'dev.txt'), os.path.join(dir_path, 'test.txt'))

    # Load the dataset files
    train_df = load_pubmed_rct_file(os.path.join(dir_path, 'train.txt'))
    dev_df   = load_pubmed_rct_file(os.path.join(dir_path, 'dev.txt'))
    test_df  = load_pubmed_rct_file(os.path.join(dir_path, 'test.txt'))

    # Print dataset stats
    print(f"Train samples: {len(train_df)}")
    print(f"Dev   samples: {len(dev_df)}")
    print(f"Test  samples: {len(test_df)}")

    X_train, y_train = train_df['sentence'], train_df['label']
    X_dev,   y_dev   = dev_df['sentence'],   dev_df['label']
    X_test,  y_test  = test_df['sentence'],  test_df['label']

    target_names = sorted(y_train.unique())
    print(f"Classes: {target_names}")

except FileNotFoundError as e:
    print(f"Error: Dataset file not found. Please ensure the files are uploaded.")
    X_train, y_train = pd.Series([], dtype=str), pd.Series([], dtype=str)
    X_dev,   y_dev   = pd.Series([], dtype=str), pd.Series([], dtype=str)
    X_test,  y_test  = pd.Series([], dtype=str), pd.Series([], dtype=str)
    target_names = []
# Out:
# Dataset/train.txt Dataset/dev.txt Dataset/test.txt
# Train samples: 180040
# Dev   samples: 30212
# Test  samples: 30135
# Classes: ['BACKGROUND', 'CONCLUSIONS', 'METHODS', 'OBJECTIVE', 'RESULTS']

# %%
# Feature Extraction and Custom Model Training
if X_train is not None and len(X_train) > 0:

    # Initialize and fit the CountVectorizer for count-based features
    count_vectorizer = CountVectorizer(
    lowercase=True,
    strip_accents='unicode',
    stop_words='english',
    ngram_range=(1, 2),   # include bigrams
    min_df=2,             # include slightly rarer words
    max_df=0.95           # drop overly common words
    )



    print("Fitting Count Vectorizer and transforming training data...")
    # // TODO: Fit the vectorizer on X_train and transform
    X_train_counts = count_vectorizer.fit_transform(X_train)

    if X_train_counts is not None:
        print(f"Vocabulary size: {X_train_counts.shape[1]}")

    print("Transforming test data...")
    # // TODO: Transform X_test using the fitted vectorizer
    X_test_counts = count_vectorizer.transform(X_test)

    # Train Custom Naive Bayes Classifier
    print("\nTraining the Custom Naive Bayes Classifier (from scratch)...")

    # // TODO: Initialize the custom NaiveBayesClassifier
    nb_model = NaiveBayesClassifier(alpha=1.0)

    # // TODO: Fit the model using X_train_counts and y_train
    nb_model.fit(X_train_counts, y_train)

    print("Training complete.")

else:
    print("Skipping feature extraction and training: Training data is empty or not loaded.")
# Out:
# Fitting Count Vectorizer and transforming training data...
# Vocabulary size: 301234
# Transforming test data...
#
# Training the Custom Naive Bayes Classifier (from scratch)...
# Training complete.

# %%
# Predict and evaluate on test set
print("\n=== Test Set Evaluation (Custom Count-Based Naive Bayes) ===")

# // TODO: Predict y_test_pred using X_test_counts
y_test_pred = nb_model.predict(X_test_counts)

if y_test_pred is not None:
    print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
    print(classification_report(y_test, y_test_pred, target_names=target_names))
    test_f1 = f1_score(y_test, y_test_pred, average='macro')
    print(f"Macro-averaged F1 score: {test_f1:.4f}")
else:
    print("Prediction step failed or incomplete.")
# Out:
# === Test Set Evaluation (Custom Count-Based Naive Bayes) ===
# Accuracy: 0.7571
#               precision    recall  f1-score   support
#
#   BACKGROUND       0.57      0.56      0.57      3621
#  CONCLUSIONS       0.63      0.69      0.66      4571
#      METHODS       0.81      0.89      0.85      9897
#    OBJECTIVE       0.60      0.43      0.50      2333
#      RESULTS       0.87      0.80      0.84      9713
#
#     accuracy                           0.76     30135
#    macro avg       0.70      0.68      0.68     30135
# weighted avg       0.76      0.76      0.75     30135
#
# Macro-averaged F1 score: 0.6825

# %%
# Confusion Matrix on test set
# // TODO: Use the confusion_matrix, matplotlib, and seaborn libraries to generate
# a visual confusion matrix (heatmap) for the predicted results.
if y_test_pred is not None:
    cm = confusion_matrix(y_test, y_test_pred)

    plt.figure(figsize=(7,6))
    sns.heatmap(cm,
                annot=True,
                fmt='d',
                cmap='Blues',
                xticklabels=target_names,
                yticklabels=target_names)

    plt.title("Confusion Matrix - Custom Count-Based Naive Bayes")
    plt.xlabel("Predicted Labels")
    plt.ylabel("True Labels")
    plt.show()
else:
    print("Confusion matrix cannot be generated: Predictions not available.")

# %% [markdown]
# # **Part B**
# TF-IDF score based Classifier

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score
)

# =======================================================
# TODO: Implement the following steps:
# 1. Define the initial `pipeline` combining TfidfVectorizer and MultinomialNB with default parameters.
# 2. Train the initial pipeline on the training data (X_train, y_train).
# 3. Predict and evaluate the performance of the initial model on the test data (X_test, y_test).
# 4. Define the `param_grid` for hyperparameter tuning.
# 5. Initialize `GridSearchCV` using the pipeline, parameter grid, and appropriate cross-validation settings.
# 6. Fit the Grid Search object using the development data (X_dev, y_dev).
# 7. Print the `best_params_` and `best_score_` found by the grid search.
# =======================================================


# // TODO: Define a Pipeline named 'pipeline' using TfidfVectorizer and MultinomialNB.
# Use standard initial parameters
pipeline = Pipeline([
    ("tfidf", TfidfVectorizer(lowercase=True, stop_words="english")),
    ("nb", MultinomialNB())
])

# // TODO: Train the initial pipeline on the training set
print("Training initial Naive Bayes pipeline...")
pipeline.fit(X_train, y_train)
print("Training complete.")


# Predict and evaluate on test set
# // TODO: Predict y_test_pred and calculate metrics
print("\n=== Test Set Evaluation (Initial Sklearn Model) ===")
y_test_pred = pipeline.predict(X_test)

if y_test_pred is not None:
    print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
    print(classification_report(y_test, y_test_pred, target_names=target_names))
    print(f"Macro-averaged F1 score: {f1_score(y_test, y_test_pred, average='macro'):.4f}")
else:
    print("Initial model evaluation skipped: Predictions not available.")


# Hyperparameter Tuning using GridSearchCV

# // TODO: Define the parameter grid 'param_grid' to tune both TF-IDF and NB parameters.
param_grid = {
    'tfidf__ngram_range': [(1, 1), (1, 2), (1, 3)],  # add trigrams
    'tfidf__min_df': [1, 2, 5],
    'tfidf__max_df': [0.9, 0.95, 1.0],
    'nb__alpha': [0.01, 0.1, 0.5, 1.0, 2.0]          # test smaller alphas
}

# // TODO: Initialize GridSearchCV using the pipeline and param_grid.
# Ensure cv=3 and scoring='f1_macro' are used.
grid = GridSearchCV(
    pipeline,
    param_grid=param_grid,
    cv=3,
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2
)

print("\nStarting Hyperparameter Tuning on Development Set...")
# // TODO: Fit the GridSearchCV object using the development data.
grid.fit(X_dev, y_dev)
print("Grid search complete.")


if grid is not None and hasattr(grid, 'best_params_'):
    # // TODO: Print the best parameters and the corresponding best cross-validation score.
    print("\n=== Grid Search Results ===")
    print("Best Parameters:", grid.best_params_)
    print(f"Best Cross-Validation Macro F1 Score: {grid.best_score_:.4f}")
else:
    print("Hyperparameter tuning skipped: Grid Search object not initialized or fitted.")
# Out:
# Training initial Naive Bayes pipeline...
# Training complete.
#
# === Test Set Evaluation (Initial Sklearn Model) ===
# Accuracy: 0.6996
#               precision    recall  f1-score   support
#
#   BACKGROUND       0.61      0.37      0.46      3621
#  CONCLUSIONS       0.61      0.55      0.57      4571
#      METHODS       0.68      0.88      0.77      9897
#    OBJECTIVE       0.72      0.09      0.16      2333
#      RESULTS       0.77      0.85      0.81      9713
#
#     accuracy                           0.70     30135
#    macro avg       0.68      0.55      0.56     30135
# weighted avg       0.69      0.70      0.67     30135
#
# Macro-averaged F1 score: 0.5555
#
# Starting Hyperparameter Tuning on Development Set...
# Fitting 3 folds for each of 135 candidates, totalling 405 fits
# Grid search complete.
#
# === Grid Search Results ===
# Best Parameters: {'nb__alpha': 0.1, 'tfidf__max_df': 0.9, 'tfidf__min_df': 5, 'tfidf__ngram_range': (1, 3)}
# Best Cross-Validation Macro F1 Score: 0.6308

# %% [markdown]
# # **Part C**
# Bayes Optimal Classifier

# %% [markdown]
# Part C Draft

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import accuracy_score, f1_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split # Used for P(h|D) calculation

# =======================================================
# TODO: Implement the following steps:
# 1. Train all five hypotheses on the sampled training data.
# 2. Compute the Posterior Weights P(h_i | D) using a validation split.
# 3. Fit the VotingClassifier using the sampled training data.
# 4. Make final predictions and evaluate the BOC performance on the test data.
# =======================================================

# Dynamic Data Sampling (DO NOT CHANGE)
BASE_SAMPLE_SIZE = 10000

# Prompt the user for their full SRN
FULL_SRN = input("Please enter your full SRN (e.g., PES1UG22CS345): ")

try:
    # Extract the last three characters and convert to integer
    if len(FULL_SRN) >= 3:
        srn_suffix_str = FULL_SRN[-3:]
        srn_value = int(srn_suffix_str)
    else:
        # Fallback if input is too short
        raise ValueError("SRN too short.")
except (ValueError, IndexError, TypeError):
    # Fallback if SRN is not entered or format is incorrect
    print("WARNING: SRN input failed or format is incorrect. Using 10000.")
    srn_value = 0

# Calculate the final sample size: 10000 + last three SRN digits
SAMPLE_SIZE = BASE_SAMPLE_SIZE + srn_value

print(f"Using dynamic sample size: {SAMPLE_SIZE}")

# Placeholder initialization in case data wasn't loaded in the environment
if 'X_train' not in locals() or len(X_train) == 0:
    print("Warning: Training data not found. Using small placeholder data.")
    X_train = pd.Series(["sample text one"] * 11000)
    y_train = pd.Series(["BACKGROUND"] * 5000 + ["METHODS"] * 6000)
    X_test = pd.Series(["test text one", "test text two"])
    y_test = pd.Series(["BACKGROUND", "METHODS"])
    target_names = ["BACKGROUND", "CONCLUSIONS", "METHODS", "OBJECTIVE", "RESULTS"]

effective_sample_size = min(SAMPLE_SIZE, len(X_train))
X_train_sampled = X_train[:effective_sample_size]
y_train_sampled = y_train[:effective_sample_size]
print(f"Actual sampled training set size used: {effective_sample_size}")


# Base TF-IDF parameters (DO NOT CHANGE)
tfidf_params = {
    'lowercase': True,
    'strip_accents': 'unicode',
    'stop_words': 'english',
    'ngram_range': (1, 2),  # unigrams + bigrams
    'min_df': 2
}


# Define the five diverse hypotheses (DO NOT CHANGE)
h1_nb = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_params)),
    ('clf', MultinomialNB(alpha=1.0, fit_prior=False))
])
h2_lr = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_params)),
    ('clf', LogisticRegression(C=2.0, solver='liblinear', multi_class='auto', max_iter=1000, random_state=42))
])
h3_rf = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_params)),
    ('clf', CalibratedClassifierCV(
        RandomForestClassifier(n_estimators=50, max_depth=10, random_state=42, n_jobs=-1), cv=3, method='isotonic'
    ))
])
h4_dt = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_params)),
    ('clf', CalibratedClassifierCV(
        DecisionTreeClassifier(max_depth=10, random_state=42), cv=3, method='isotonic'
    ))
])
h5_knn = Pipeline([
    ('tfidf', TfidfVectorizer(**tfidf_params)),
    ('clf', CalibratedClassifierCV(
        KNeighborsClassifier(n_neighbors=5, n_jobs=-1), cv=3, method='isotonic'
    ))
])

hypotheses = [h1_nb, h2_lr, h3_rf, h4_dt, h5_knn]
hypothesis_names = ['NaiveBayes', 'LogisticRegression', 'RandomForest', 'DecisionTree', 'KNN']


# =======================================================
# Training and BOC Implementation
# =======================================================

# // TODO: Train all five hypotheses on X_train_sampled and y_train_sampled using a for loop.
print("\nTraining all base models...")
for name, model in zip(hypothesis_names, hypotheses):
    print(f"Training {name} ...")
    model.fit(X_train_sampled, y_train_sampled)
print("All base models trained.")


# // TODO: Implement the Posterior Weight Calculation (P(h_i | D)).
print("\nCalculating Posterior Weights P(h_i | D)...")
X_subtrain, X_val, y_subtrain, y_val = train_test_split(
    X_train_sampled, y_train_sampled, test_size=0.3, stratify=y_train_sampled, random_state=42
)

log_liks = []
for name, model in zip(hypothesis_names, hypotheses):
    model.fit(X_subtrain, y_subtrain)
    if hasattr(model, "predict_proba"):
        probs = model.predict_proba(X_val)
        # extract probability for correct class per sample
        cls_map = {c:i for i,c in enumerate(model.classes_)}
        p_true = []
        for i, true_label in enumerate(y_val):
            if true_label in cls_map:
                p = probs[i, cls_map[true_label]]
            else:
                p = 1e-12
            p_true.append(max(p, 1e-12))
        log_lik = np.sum(np.log(p_true))
    else:
        preds = model.predict(X_val)
        acc = np.mean(preds == y_val)
        log_lik = len(y_val) * np.log(max(acc, 1e-12))
    log_liks.append(log_lik)

# Normalize to posterior weights
max_ll = max(log_liks)
unnorm_weights = [np.exp(ll - max_ll) for ll in log_liks]
posterior_weights = [w / sum(unnorm_weights) for w in unnorm_weights]
print("Posterior Weights:", posterior_weights)


# Implement and Evaluate the Bayes Optimal Classifier
estimators = list(zip(hypothesis_names, hypotheses))

# BOC is approximated using soft voting with posterior weights
boc_soft_voter = VotingClassifier(
    estimators=estimators,
    voting='soft',
    weights=posterior_weights,
    n_jobs=-1
)

print("\nFitting the VotingClassifier (BOC approximation)...")
# // TODO: Fit the VotingClassifier using the full sampled training data (X_train_sampled, y_train_sampled)
boc_soft_voter.fit(X_train_sampled, y_train_sampled)
print("Fitting complete.")


# Make the final BOC prediction on the test set
print("\nPredicting on test set...")
# // TODO: Predict y_pred using X_test, and then calculate and visualize evaluation metrics.
y_pred = boc_soft_voter.predict(X_test)


# Final Evaluation (STUDENT TASK)
print("\n=== Final Evaluation: Bayes Optimal Classifier (Soft Voting) ===")

if y_pred is not None:
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='macro')
    print(f"Accuracy: {acc:.4f}")
    print(f"Macro-averaged F1 score: {f1:.4f}")
    print(classification_report(y_test, y_pred, target_names=target_names))

    # // TODO: Generate and visualize the Confusion Matrix (heatmap) for the BOC predictions.
    cm = confusion_matrix(y_test, y_pred, labels=target_names)
    plt.figure(figsize=(7,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
                xticklabels=target_names, yticklabels=target_names)
    plt.title("Confusion Matrix - Bayes Optimal Classifier (Soft Voting)")
    plt.xlabel("Predicted Labels") 
    plt.ylabel("True Labels")
    plt.show()
else:
    print("Evaluation skipped: Predictions not generated.")
# Out:
# Please enter your full SRN (e.g., PES1UG22CS345): PES2UG23CS906
# Using dynamic sample size: 10906
# Actual sampled training set size used: 10906
#
# Training all base models...
# Training NaiveBayes ...
# Training LogisticRegression ...
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# Training RandomForest ...
# Training DecisionTree ...
# Training KNN ...
# All base models trained.
#
# Calculating Posterior Weights P(h_i | D)...
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# Posterior Weights: [np.float64(7.444653567638392e-118), np.float64(1.0), np.float64(2.3462014409648893e-128), np.float64(0.0), np.float64(0.0)]
#
# Fitting the VotingClassifier (BOC approximation)...
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# /home/mona/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1296: FutureWarning: Using the 'liblinear' solver for multiclass classification is deprecated. An error will be raised in 1.8. Either use another solver which supports the multinomial loss or wrap the estimator in a OneVsRestClassifier to keep applying a one-versus-rest scheme.
#   warnings.warn(
# Fitting complete.
#
# Predicting on test set...
#
# === Final Evaluation: Bayes Optimal Classifier (Soft Voting) ===
# Accuracy: 0.7215
# Macro-averaged F1 score: 0.6321
#               precision    recall  f1-score   support
#
#   BACKGROUND       0.58      0.40      0.47      3621
#  CONCLUSIONS       0.61      0.58      0.60      4571
#      METHODS       0.73      0.89      0.80      9897
#    OBJECTIVE       0.63      0.39      0.48      2333
#      RESULTS       0.81      0.82      0.81      9713
#
#     accuracy                           0.72     30135
#    macro avg       0.67      0.61      0.63     30135
# weighted avg       0.71      0.72      0.71     30135
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.3s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=  -0.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.0s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   0.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.0s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.8s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   0.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.8s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   0.9s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.4s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=  -0.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.0s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   0.0s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   0.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   0.3s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.3s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   0.4s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.9s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.8s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   2.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   0.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.3s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   0.9s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.3s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.2s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.0s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.9s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.5s
# [CV] END nb__alpha=0.01, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=0.01, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=0.1, tfidf__max_df=0.95, tfidf__min_df=2, tfidf__ngram_range=(1, 3); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=0.1, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=  -0.1s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   0.9s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.7s
# [CV] END nb__alpha=0.5, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.4s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.5s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   2.8s
# [CV] END nb__alpha=1.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 3); total time=   1.7s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.1s
# [CV] END nb__alpha=1.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2); total time=   1.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 1); total time=   0.5s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.9, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.0s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.6s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   1.8s
# [CV] END nb__alpha=2.0, tfidf__max_df=0.95, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.1s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 1); total time=   0.7s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=1, tfidf__ngram_range=(1, 3); total time=   3.2s
# [CV] END nb__alpha=2.0, tfidf__max_df=1.0, tfidf__min_df=5, tfidf__ngram_range=(1, 2); total time=   1.2s
